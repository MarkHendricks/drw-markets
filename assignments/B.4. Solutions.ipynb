# %% [markdown]
# # B.4. Solutions
#
# ## Module B: Currency, Commodities, and Equity
#
# ### DRW New-Hire Learning Program
#
# #### Summer 2022
#
# Questions?
# * Contact: Mark Hendricks
# * hendricks@uchicago.edu
#
#
# ### Instructions
#
# * Work on this in your group.
# * Don't spend more than **60** minutes on it during the 12-2pm break. (We want you to have time refresh and eat.)
# * We encourage you to do more on the problems in the afternoon/evening.
#
# ### Revisions
#
# <span style="color:red">Revisions are in RED below.</span>
# * Pardon the confusion of some bad data.
# * Use the new data file with all synchronous prices to get tighter put-call parity bounds.
#
# **No need to adjust your solutions to these revisions if you prefer to stick with the old parameters, or to adaptations you already made.**

# %% [markdown]
# # Core Analysis

# %% [markdown]
# Use the data in **<span style="color:red">data/options_chains_v2.xlsx</span>** regarding `TSLA` as quoted at the end of <span style="color:red">July 21, 2022</span>

# %% [markdown]
# ## 1 The Option Chain
#
#
#
# ### 1.1
# Using
# * expiration = Aug 19, 2022
#
# Plot the market quoted prices of the puts and calls throughout the chain. Plot them against the strike price.
#
# ### 1.2
# Make the same plot, but instead of market prices of puts and calls, plot the implied volatility of each against the strike price.
#
# What do you notice about this graph? (We will be discussing implied volatility more tomorrow. For now, just focus on the main feature of the graph.)
#
# ### 1.3
#
# Suppose that we want to buy 100 units of
# * Dec 16 puts at strike of <span style="color:red">\\$700</span>
# * Dec 16 calls at strike of <span style="color:red">\\$1,000</span>
#
# What is the net cost to set up this position today?
#
# Make a plot of the total net profit on Dec 16, as a function of the future stock price. Include the cost of setting up the position in the net profit.

# %% [markdown]
# ## 2 Put-Call Parity

# %% [markdown]
# For the analysis, focus on the options with
# * expiration = Aug 19, 2022
# * strike = <span style="color:red">\$750</span>
#
# For the interest rate, use SOFR.
# * The 3-month Tbill rate is provided if you want to additionally try that to see the difference.
#
# ### 2.1
#
# If this were a Euorpean option, what would put-call parity suggest the price of the call should be?
# * Note that TSLA does not pay dividends.
#
# ### 2.2
# Compare this to the actual price of the call.
#
# Suppose that we trust the put-call parity relationship more than the market quote of the call. What trade does this suggest? Be specific.
#
# ### 2.3
# Now consider that this is an American option, so put-call parity gives an interval of prices rather than a specific price.
#
# Report this range. Is the market quote inside the interval?
#
# ### 2.4
#
# Redo the problem above, but this time for the TSLA calls with
# * maturity = Dec 16, 2022
# * strike = <span style="color:red">\$900</span>

# %% [markdown]
# ***

# %% [markdown]
# # Extra Analysis

# %% [markdown]
# ## 3 Black-Scholes
#
# Consider the put and call options on TSLA
# * Strike = <span style="color:red">\$750</span>
# * Expiration = August 19, 2022.
#
# Though these are American options, ignore that and treat them as European.
#
# ### 3.1
# Use Black-Scholes to calculate today's value of the put and call.
# * Assume annualized volatility of 55\%.
#
# Graph the value of the call against the price of the stock, holding the time-to-maturity constant at today.
#
# ### 3.2
# Instead of assuming a volatility and solving for the call value, do the opposite. Assume the call value is the market's quoted price. Solve for the implied volatility that makes this true.
#
# Report the calculated implied volatility.
#
# #### Hint
# For solving for the implied volatility, you may want to use
# `from scipy.optimize import fsolve`
#
# ### 3.3
# Re-do the previous questions for the put options on TSLA
# * Strike = <span style="color:red">\$900</span>
# * Expiration = December 16, 2022.

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:red">Solutions</span>

# %%
import pandas as pd
import numpy as np
import datetime
import warnings

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,6)
plt.rcParams['font.size'] = 15
plt.rcParams['legend.fontsize'] = 13

from matplotlib.ticker import (MultipleLocator,
                               FormatStrFormatter,
                               AutoMinorLocator)
import sys
sys.path.insert(0, '../cmds')
from options import *

# %% [markdown]
# ## <span style="color:red">Solution 1</span>

# %%
LOADFILE = '../data/options_chains_v2.xlsx'
quotes = pd.read_excel(LOADFILE).set_index('date')

QDATE = quotes.index[0]
TICK = quotes.columns[-1]

EXPRY = [expry.strftime('%Y-%m-%d') for expry in quotes.index[1:]]

# %%
calls = dict()
puts = dict()

for expry in EXPRY:
    calls[expry] = pd.read_excel(LOADFILE,sheet_name=f'CALLS {expry}').set_index('strike')
    puts[expry] = pd.read_excel(LOADFILE,sheet_name=f'PUTS {expry}').set_index('strike')

# %% [markdown]
# ### 1.1

# %%
pd.concat([calls[EXPRY[0]]['lastPrice'],puts[EXPRY[0]]['lastPrice']],axis=1).plot(linestyle='',marker='o',markersize=10,ylabel='market price', title='Option Price vs Strike')
plt.legend(['calls','puts']);

# %% [markdown]
# ### 1.2

# %%
pd.concat([calls[EXPRY[0]]['impliedVolatility'],puts[EXPRY[0]]['impliedVolatility']],axis=1).plot(linestyle='',marker='o',markersize=10,ylabel='implied volatility', title='Implied Volatility vs Strike')
plt.legend(['calls','puts']);

# %% [markdown]
# ### 1.3

# %%
Kput = 700
Kcall = 1000
N = 100

premium = calls[EXPRY[1]].loc[Kcall,'lastPrice'] - puts[EXPRY[1]].loc[Kput,'lastPrice']

stockgrid = np.arange(500,1200)

holdings = pd.DataFrame(index=stockgrid, columns=['net profit'], dtype=float)
holdings['stock'] = stockgrid
holdings['cost'] = -premium
holdings['put payoff'] = (Kput - stockgrid > 0) * (Kput-stockgrid)
holdings['call payoff'] = (stockgrid-Kcall > 0) * (-(stockgrid - Kcall))
holdings['net profit'] = holdings.sum(axis=1) *N

# %%
print(f'Net cost (receipt) for setting up options position is ${N*premium:.2f}.')
holdings['net profit'].plot(title='Net Profit',ylabel='net profit',xlabel=f'{TICK} price');
# Out:
# Net cost (receipt) for setting up options position is $-930.00.

# %% [markdown]
# ## <span style="color:red">Solution 2</span>

# %%
STRIKES = [750,900]
USE_SOFR = False

if USE_SOFR:
    rf = quotes.loc[QDATE,'SOFR']
else:
    rf = quotes.loc[QDATE,'TBill (3mo)']
    
S = quotes.loc[QDATE,TICK]

# %%
parity = dict()

for i, expry in enumerate(EXPRY):
    K = STRIKES[i]
    parity[expry] = pd.DataFrame(index=[K],columns=['lower','market','upper'],dtype=float)

    c = calls[expry].loc[K,'lastPrice']
    p = puts[expry].loc[K,'lastPrice']

    tau = to_maturity(expiration=expry, current_date=QDATE)
    disc = np.exp(-rf * tau)

    parity[expry].loc[K,['lower','upper']] = [S-K,S-disc * K]
    parity[expry].loc[K,'market'] = c-p

# %% [markdown]
# ### Call - Put Spread

# %%
pd.concat(parity,axis=1).sort_index().style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0636c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0636c_level0_col0" class="col_heading level0 col0" colspan="3">2022-08-19</th>
#       <th id="T_0636c_level0_col3" class="col_heading level0 col3" colspan="3">2022-12-16</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_0636c_level1_col0" class="col_heading level1 col0" >lower</th>
#       <th id="T_0636c_level1_col1" class="col_heading level1 col1" >market</th>
#       <th id="T_0636c_level1_col2" class="col_heading level1 col2" >upper</th>
#       <th id="T_0636c_level1_col3" class="col_heading level1 col3" >lower</th>
#       <th id="T_0636c_level1_col4" class="col_heading level1 col4" >market</th>
#       <th id="T_0636c_level1_col5" class="col_heading level1 col5" >upper</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0636c_level0_row0" class="row_heading level0 row0" >750</th>
#       <td id="T_0636c_row0_col0" class="data row0 col0" >65.12</td>
#       <td id="T_0636c_row0_col1" class="data row0 col1" >65.58</td>
#       <td id="T_0636c_row0_col2" class="data row0 col2" >66.52</td>
#       <td id="T_0636c_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_0636c_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_0636c_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0636c_level0_row1" class="row_heading level0 row1" >900</th>
#       <td id="T_0636c_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_0636c_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_0636c_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_0636c_row1_col3" class="data row1 col3" >-84.88</td>
#       <td id="T_0636c_row1_col4" class="data row1 col4" >-73.01</td>
#       <td id="T_0636c_row1_col5" class="data row1 col5" >-76.31</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## <span style="color:red">Solution 3</span>

# %%
IVOL = .55

# %%
pricing_C = pd.DataFrame(columns=['Black-Scholes','Market'],index=EXPRY,dtype=float)
pricing_P = pd.DataFrame(columns=['Black-Scholes','Market'],index=EXPRY,dtype=float)

for i,expry in enumerate(EXPRY):
    K = STRIKES[i]
    tau = to_maturity(expiration=expry, current_date=QDATE)
    
    pricing_C.loc[expry,'Black-Scholes'] = bs_price(under=S,strike=K,T=tau,rf=rf,vol=IVOL)
    pricing_C.loc[expry, 'Market'] = calls[expry].loc[K,'lastPrice']
    
    pricing_P.loc[expry,'Black-Scholes'] = bs_price(under=S,strike=K,T=tau,rf=rf,vol=IVOL)
    pricing_P.loc[expry, 'Market'] = puts[expry].loc[K,'lastPrice']
    
pricing = pd.concat([pricing_C,pricing_P],axis=1,keys=['Call','Put'])

# %% [markdown]
# ### (a)

# %%
pricing.style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0e3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0e3c_level0_col0" class="col_heading level0 col0" colspan="2">Call</th>
#       <th id="T_d0e3c_level0_col2" class="col_heading level0 col2" colspan="2">Put</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_d0e3c_level1_col0" class="col_heading level1 col0" >Black-Scholes</th>
#       <th id="T_d0e3c_level1_col1" class="col_heading level1 col1" >Market</th>
#       <th id="T_d0e3c_level1_col2" class="col_heading level1 col2" >Black-Scholes</th>
#       <th id="T_d0e3c_level1_col3" class="col_heading level1 col3" >Market</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0e3c_level0_row0" class="row_heading level0 row0" >2022-08-19</th>
#       <td id="T_d0e3c_row0_col0" class="data row0 col0" >88.66</td>
#       <td id="T_d0e3c_row0_col1" class="data row0 col1" >93.58</td>
#       <td id="T_d0e3c_row0_col2" class="data row0 col2" >88.66</td>
#       <td id="T_d0e3c_row0_col3" class="data row0 col3" >28.00</td>
#     </tr>
#     <tr>
#       <th id="T_d0e3c_level0_row1" class="row_heading level0 row1" >2022-12-16</th>
#       <td id="T_d0e3c_row1_col0" class="data row1 col0" >84.27</td>
#       <td id="T_d0e3c_row1_col1" class="data row1 col1" >94.50</td>
#       <td id="T_d0e3c_row1_col2" class="data row1 col2" >84.27</td>
#       <td id="T_d0e3c_row1_col3" class="data row1 col3" >167.51</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### (b)

# %%
pxgrid = np.arange(S/2,S*1.5)

BSvals = dict()
for i,expry in enumerate(EXPRY):
    BSvals[expry] = pd.DataFrame(index=pxgrid,columns=['Call','Put'],dtype=float)

    K = STRIKES[i]
    tau = to_maturity(expiration=expry, current_date=QDATE)
    
    for px in pxgrid:
        BSvals[expry].loc[px,'Call'] = bs_price(under=px,strike=K,T=tau,rf=rf,vol=IVOL)
        BSvals[expry].loc[px,'Put'] = bs_price(under=px,strike=K,T=tau,rf=rf,vol=IVOL,option='put')

# %%
fig, ax = plt.subplots(2,1,figsize=(10,10))
for i, expry in enumerate(EXPRY):
    BSvals[expry].plot(ax=ax[i], xlabel='stock price',ylabel='BS option price',title=f'Black Scholes Value - Expiration: {expry}');
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.2
#
# The implied volatility calculations are below.
#
# Note that these are **American** options, yet we are calculating implied volatility with the Black-Scholes formula. Thus, the calculated volatilities will be biased upwards compared to the quoted American implied vols.

# %%
px_optC = calls[expry].loc[K,'lastPrice']
px_optP = puts[expry].loc[K,'lastPrice']

ivolBS = pd.DataFrame(index=EXPRY, columns=['call','put'],dtype=float)
ivolQuote = pd.DataFrame(index=EXPRY, columns=['call','put'],dtype=float)

IVOL0 = .55

for i, expry in enumerate(EXPRY):
    K = STRIKES[i]
    tau = to_maturity(expiration=expry,current_date=QDATE)

    ivolBS.loc[expry,'call'] = bs_impvol(under=S,strike=K,T=tau,rf=rf,option='call',opt_price=px_optC,volGuess=IVOL0)
    ivolBS.loc[expry,'put'] = bs_impvol(under=S,strike=K,T=tau,rf=rf,option='call',opt_price=px_optP,volGuess=IVOL0)
    
    ivolQuote.loc[expry,'call'] = calls[expry].loc[K,'impliedVolatility']
    ivolQuote.loc[expry,'put'] = puts[expry].loc[K,'impliedVolatility']
    
ivol = pd.concat([ivolBS,ivolQuote],axis=1,keys=['calculated','quoted'])
ivol.style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea64a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea64a_level0_col0" class="col_heading level0 col0" colspan="2">calculated</th>
#       <th id="T_ea64a_level0_col2" class="col_heading level0 col2" colspan="2">quoted</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_ea64a_level1_col0" class="col_heading level1 col0" >call</th>
#       <th id="T_ea64a_level1_col1" class="col_heading level1 col1" >put</th>
#       <th id="T_ea64a_level1_col2" class="col_heading level1 col2" >call</th>
#       <th id="T_ea64a_level1_col3" class="col_heading level1 col3" >put</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea64a_level0_row0" class="row_heading level0 row0" >2022-08-19</th>
#       <td id="T_ea64a_row0_col0" class="data row0 col0" >62.62%</td>
#       <td id="T_ea64a_row0_col1" class="data row0 col1" >150.88%</td>
#       <td id="T_ea64a_row0_col2" class="data row0 col2" >63.56%</td>
#       <td id="T_ea64a_row0_col3" class="data row0 col3" >62.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ea64a_level0_row1" class="row_heading level0 row1" >2022-12-16</th>
#       <td id="T_ea64a_row1_col0" class="data row1 col0" >59.95%</td>
#       <td id="T_ea64a_row1_col1" class="data row1 col1" >95.34%</td>
#       <td id="T_ea64a_row1_col2" class="data row1 col2" >60.65%</td>
#       <td id="T_ea64a_row1_col3" class="data row1 col3" >55.97%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.3
#
# See above.
